# %% [markdown]
# LangChain V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["Groq_API_key"] = os.getenv("Groq_API_key")

# %%
from langchain.agents import create_agent

agent = create_agent(
    model = "groq",
    tools = [],
    system_prompt = "You are a helpful assistant.",
    verbose = True
)
agent
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain.agents import create_agent
#       2
#       3 agent = create_agent(
#       4     model = "groq",
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain\agents\__init__.py:3
#       1 """Entrypoint to building [Agents](https://docs.langchain.com/oss/python/langchain/agents) with LangChain."""  # noqa: E501
# ----> 3 from langchain.agents.factory import create_agent
#       4 from langchain.agents.middleware.types import AgentState
#       6 __all__ = [
#       7     "AgentState",
#       8     "create_agent",
#       9 ]
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain\agents\factory.py:21
#       9 from dataclasses import dataclass, field, fields
#      10 from typing import (
#      11     TYPE_CHECKING,
#      12     Annotated,
#    (...)     18     get_type_hints,
#      19 )
# ---> 21 from langchain_core.language_models.chat_models import BaseChatModel
#      22 from langchain_core.messages import AIMessage, AnyMessage, SystemMessage, ToolMessage
#      23 from langchain_core.tools import BaseTool
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:41
#      30 from langchain_core.language_models._compat_bridge import (
#      31     achunks_to_events,
#      32     amessage_to_events,
#      33     chunks_to_events,
#      34     message_to_events,
#      35 )
#      36 from langchain_core.language_models._utils import (
#      37     _filter_invocation_params_for_tracing,
#      38     _normalize_messages,
#      39     _update_message_content_to_blocks,
#      40 )
# ---> 41 from langchain_core.language_models.base import (
#      42     BaseLanguageModel,
#      43     LangSmithParams,
#      44     LanguageModelInput,
#      45 )
#      46 from langchain_core.language_models.chat_model_stream import (
#      47     AsyncChatModelStream,
#      48     ChatModelStream,
#      49 )
#      50 from langchain_core.language_models.model_profile import (
#      51     ModelProfile,
#      52     _warn_unknown_profile_keys,
#      53 )
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\base.py:37
#      25 from langchain_core.messages import (
#      26     AIMessage,
#      27     AnyMessage,
#    (...)     30     get_buffer_string,
#      31 )
#      32 from langchain_core.prompt_values import (
#      33     ChatPromptValueConcrete,
#      34     PromptValue,
#      35     StringPromptValue,
#      36 )
# ---> 37 from langchain_core.runnables import Runnable, RunnableSerializable
#      39 if TYPE_CHECKING:
#      40     from langchain_core.outputs import LLMResult
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\runnables\__init__.py:130, in __getattr__(attr_name)
#     128 def __getattr__(attr_name: str) -> object:
#     129     module_name = _dynamic_imports.get(attr_name)
# --> 130     result = import_attr(attr_name, module_name, __spec__.parent)
#     131     globals()[attr_name] = result
#     132     return result
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\_import_utils.py:36, in import_attr(attr_name, module_name, package)
#      34 else:
#      35     try:
# ---> 36         module = import_module(f".{module_name}", package=package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\runnables\base.py:87
#      66 from langchain_core.runnables.utils import (
#      67     AddableDict,
#      68     AnyConfigurableField,
#    (...)     84     is_async_generator,
#      85 )
#      86 from langchain_core.tracers._streaming import _StreamingCallbackHandler
# ---> 87 from langchain_core.tracers.event_stream import (
#      88     _astream_events_implementation_v1,
#      89     _astream_events_implementation_v2,
#      90 )
#      91 from langchain_core.tracers.log_stream import (
#      92     LogStreamCallbackHandler,
#      93     _astream_log_implementation,
#      94 )
#      95 from langchain_core.tracers.root_listeners import (
#      96     AsyncRootListenersTracer,
#      97     RootListenersTracer,
#      98 )
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\tracers\event_stream.py:38
#      32 from langchain_core.runnables.utils import (
#      33     Input,
#      34     Output,
#      35     _RootEventFilter,
#      36 )
#      37 from langchain_core.tracers._streaming import _StreamingCallbackHandler
# ---> 38 from langchain_core.tracers.log_stream import (
#      39     LogStreamCallbackHandler,
#      40     RunLog,
#      41     _astream_log_implementation,
#      42 )
#      43 from langchain_core.tracers.memory_stream import _MemoryStream
#      44 from langchain_core.utils.aiter import aclosing
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\tracers\log_stream.py:28
#      26 from langchain_core.runnables import RunnableConfig, ensure_config
#      27 from langchain_core.tracers._streaming import _StreamingCallbackHandler
# ---> 28 from langchain_core.tracers.base import BaseTracer
#      29 from langchain_core.tracers.memory_stream import _MemoryStream
#      31 if TYPE_CHECKING:
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\tracers\base.py:17
#      15 from langchain_core.callbacks.base import AsyncCallbackHandler, BaseCallbackHandler
#      16 from langchain_core.exceptions import TracerException  # noqa: F401
# ---> 17 from langchain_core.tracers.core import _TracerCore
#      19 if TYPE_CHECKING:
#      20     from collections.abc import Sequence
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\tracers\core.py:18
#      16 from langchain_core.exceptions import TracerException
#      17 from langchain_core.load import dumpd
# ---> 18 from langchain_core.tracers.schemas import Run
#      20 if TYPE_CHECKING:
#      21     from collections.abc import Coroutine, Sequence
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langchain_core\tracers\schemas.py:5
#       1 """Schemas for tracers."""
#       3 from __future__ import annotations
# ----> 5 from langsmith import RunTree
#       7 # Begin V2 API Schemas
#      10 Run = RunTree  # For backwards compatibility
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langsmith\__init__.py:75, in __getattr__(name)
#      73     return AsyncClient
#      74 elif name == "RunTree":
# ---> 75     from langsmith.run_trees import RunTree
#      77     return RunTree
#      78 elif name == "EvaluationResult":
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langsmith\run_trees.py:23
#      21 from langsmith import schemas as ls_schemas
#      22 from langsmith import utils
# ---> 23 from langsmith._internal._uuid import uuid7, uuid7_deterministic
#      24 from langsmith.client import ID_TYPE, RUN_TYPE_T, Client, _dumps_json, _ensure_uuid
#      25 from langsmith.uuid import uuid7_from_datetime
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\langsmith\_internal\_uuid.py:10
#       7 import warnings
#       8 from typing import Final
# ---> 10 import xxhash
#      11 from uuid_utils.compat import uuid7 as _uuid_utils_uuid7
#      13 _NANOS_PER_SECOND: Final = 1_000_000_000
#
# File c:\Users\tiwar\Langchainupdated\.venv\Lib\site-packages\xxhash\__init__.py:1
# ----> 1 from ._xxhash import (
#       2     xxh32,
#       3     xxh32_digest,
#       4     xxh32_intdigest,
#       5     xxh32_hexdigest,
#       6     xxh64,
#       7     xxh64_digest,
#       8     xxh64_intdigest,
#       9     xxh64_hexdigest,
#      10     xxh3_64,
#      11     xxh3_64_digest,
#      12     xxh3_64_intdigest,
#      13     xxh3_64_hexdigest,
#      14     xxh3_128,
#      15     xxh3_128_digest,
#      16     xxh3_128_intdigest,
#      17     xxh3_128_hexdigest,
#      18     XXHASH_VERSION,
#      19 )
#      21 from .version import VERSION, VERSION_TUPLE
#      24 xxh128 = xxh3_128
#
# ImportError: DLL load failed while importing _xxhash: An Application Control policy has blocked this file.
